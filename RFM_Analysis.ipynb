# %%
#laoding required libraries
import pandas as pd # for dataframes
import matplotlib.pyplot as plt # for plotting graphs
import seaborn as sns # for plotting graphs
import datetime as dt
import warnings
warnings.filterwarnings(action='ignore')

# %%
#loading the data
transcations_df= pd.read_excel(r"/Users/naveen/Desktop/KPMG Virtual Internship/KPMG_VI_New_raw_data_update_final.xlsx", 
                    sheet_name='Transactions')

# %%
transcations_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# 0       71.49          53.62              2012-12-02
# 1     2091.47         388.92              2014-03-03
# 2     1793.43         248.82              1999-07-20
# 3     1198.46         381.10              1998-12-16
# 4     1765.30         709.48              2015-08-10

# %%
#loading the data
newcustomer_df= pd.read_excel(r"/Users/naveen/Desktop/KPMG Virtual Internship/KPMG_VI_New_raw_data_update_final.xlsx", 
                    sheet_name='NewCustomerList')

# %%
newcustomer_df.head(2)
# Out:
#   first_name last_name gender  past_3_years_bike_related_purchases        DOB  \
# 0    Chickie   Brister   Male                                   86 1957-07-12
# 1      Morly    Genery   Male                                   69 1970-03-22
#
#              job_title job_industry_category wealth_segment  \
# 0      General Manager         Manufacturing  Mass Customer
# 1  Structural Engineer              Property  Mass Customer
#
#   deceased_indicator owns_car  ...  state    country  property_valuation  \
# 0                  N      Yes  ...    QLD  Australia                   6
# 1                  N       No  ...    NSW  Australia                  11
#
#   Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Rank  \
# 0        0.89      1.1125     1.390625     1.182031            1     1
# 1        0.82      0.8200     1.025000     0.871250            1     1
#
#      Value
# 0  1.71875
# 1  1.71875
#
# [2 rows x 23 columns]

# %%
#loading the data
customerdemographic_df= pd.read_excel(r"/Users/naveen/Desktop/KPMG Virtual Internship/KPMG_VI_New_raw_data_update_final.xlsx", 
                    sheet_name='CustomerDemographic')

# %%
customerdemographic_df.head(2)
# Out:
#    customer_id first_name  last_name gender  \
# 0            1    Laraine  Medendorp      F
# 1            2        Eli    Bockman   Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
#
#   job_industry_category wealth_segment deceased_indicator  \
# 0                Health  Mass Customer                  N
# 1    Financial Services  Mass Customer                  N
#
#                         default owns_car  tenure
# 0                            "'      Yes    11.0
# 1  <script>alert('hi')</script>      Yes    16.0

# %%
customerdemographic_df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
#loading the data
CustomerAddress_df= pd.read_excel(r"/Users/naveen/Desktop/KPMG Virtual Internship/KPMG_VI_New_raw_data_update_final.xlsx", 
                    sheet_name='CustomerAddress')

# %%
CustomerAddress_df.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
transcations_df.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#newcustomer_df.isnull().sum()

# %%
customerdemographic_df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
CustomerAddress_df.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
mergedata=transcations_df.merge(customerdemographic_df,
                                left_on = 'customer_id',
                                right_on = 'customer_id',
                                how = 'left')

# %%
mergedata.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved   Trek Bicycles     Standard        medium        large  ...
# 2     Approved      OHM Cycles     Standard           low       medium  ...
# 3     Approved  Norco Bicycles     Standard        medium       medium  ...
# 4     Approved  Giant Bicycles     Standard        medium        large  ...
#
#    gender  past_3_years_bike_related_purchases        DOB  \
# 0    Male                                 19.0 1955-01-11
# 1  Female                                 89.0 1979-02-04
# 2    Male                                  9.0 1977-06-03
# 3    Male                                 83.0 1962-01-14
# 4  Female                                 29.0 1996-12-15
#
#                     job_title job_industry_category     wealth_segment  \
# 0         Software Engineer I    Financial Services      Mass Customer
# 1         Clinical Specialist                Health      Mass Customer
# 2  Desktop Support Technician                Retail  Affluent Customer
# 3             Staff Scientist    Financial Services      Mass Customer
# 4                         NaN                Retail  Affluent Customer
#
#    deceased_indicator                                            default  \
# 0                   N                                   ã»(ï¿£âï¿£)ã»:*:
# 1                   N             ZÌ®ÌÍÌ ÍÍAÌ¥ÌÌÍÌ»ÌLÌ£ÍÍÌ¯Ì¹ÌÍGÌ»OÌ­ÌÌ®
# 2                   N                                       testâ testâ«
# 3                   N                                          â°â´âµâââ
# 4                   N  Ì¡ÍÍÌIÍÌÌÌ¦nÍÍÍvÌ®Ì«okÌ²Ì«ÌÍiÌÍÌ­Ì¹Ì ÌnÌ¡Ì»Ì®Ì...
#
#   owns_car tenure
# 0      Yes   10.0
# 1      Yes   10.0
# 2       No   22.0
# 3       No   16.0
# 4      Yes    2.0
#
# [5 rows x 25 columns]

# %%
mergedata.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
rfm_df=mergedata[['product_id', 'customer_id', 'transaction_date','list_price','standard_cost']]

# %%
rfm_df
# Out:
#        product_id  customer_id transaction_date  list_price  standard_cost
# 0               2         2950       2017-02-25       71.49          53.62
# 1               3         3120       2017-05-21     2091.47         388.92
# 2              37          402       2017-10-16     1793.43         248.82
# 3              88         3135       2017-08-31     1198.46         381.10
# 4              78          787       2017-10-01     1765.30         709.48
# ...           ...          ...              ...         ...            ...
# 19995          51         1018       2017-06-24     2005.66        1203.40
# 19996          41          127       2017-11-09      416.98         312.74
# 19997          87         2284       2017-04-14     1636.90          44.71
# 19998           6         2764       2017-07-03      227.88         136.73
# 19999          11         1144       2017-09-22     1775.81        1580.47
#
# [20000 rows x 5 columns]

# %%
Present=rfm_df['transaction_date'].max()

# %%
Present
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
rfm_df['profit']=rfm_df['list_price']-rfm_df['standard_cost']

# %%
rfm=rfm_df.groupby('customer_id').agg({'transaction_date': lambda date: round((Present - date.max()).days),
                                  'product_id': lambda num: len(num),
                                  'profit': lambda price: round(price.sum(), 4)})

# %%
rfm
# Out:
#              transaction_date  product_id    profit
# customer_id
# 1                           7          11  3018.090
# 2                         128           3  2226.260
# 3                         102           8  3362.810
# 4                         195           2   220.570
# 5                          16           6  2394.940
# ...                       ...         ...       ...
# 3497                       52           3  1648.320
# 3498                      127           6  3147.330
# 3499                       51           7  4955.250
# 3500                      144           6  1785.860
# 5034                       84           3   269.485
#
# [3494 rows x 3 columns]

# %%
rfm.columns=['recency','frequency','monetary']

# %%
rfm
# Out:
#              recency  frequency  monetary
# customer_id
# 1                  7         11  3018.090
# 2                128          3  2226.260
# 3                102          8  3362.810
# 4                195          2   220.570
# 5                 16          6  2394.940
# ...              ...        ...       ...
# 3497              52          3  1648.320
# 3498             127          6  3147.330
# 3499              51          7  4955.250
# 3500             144          6  1785.860
# 5034              84          3   269.485
#
# [3494 rows x 3 columns]

# %%
rfm['r_quartile'] = pd.qcut(rfm['recency'].rank(method='first'), 4, ['4', '3', '2', '1'])

# %%
rfm['m_quartile'] = pd.qcut(rfm['monetary'].rank(method='first'), 4, ['1', '2', '3', '4'])

# %%
rfm['f_quartile'] = pd.qcut(rfm['frequency'].rank(method='first'), 4, ['1', '2', '3', '4'])

# %%
rfm.describe()
# Out:
#            recency    frequency      monetary
# count  3494.000000  3494.000000   3494.000000
# mean     60.813681     5.724098   3128.301078
# std      57.787120     2.325873   1770.536034
# min       0.000000     1.000000     15.080000
# 25%      17.000000     4.000000   1841.370000
# 50%      44.000000     6.000000   2861.980000
# 75%      85.000000     7.000000   4183.107500
# max     353.000000    14.000000  11668.950000

# %%
rfm
# Out:
#              recency  frequency  monetary r_quartile m_quartile f_quartile
# customer_id
# 1                  7         11  3018.090          4          3          4
# 2                128          3  2226.260          1          2          1
# 3                102          8  3362.810          1          3          4
# 4                195          2   220.570          1          1          1
# 5                 16          6  2394.940          4          2          2
# ...              ...        ...       ...        ...        ...        ...
# 3497              52          3  1648.320          2          1          1
# 3498             127          6  3147.330          1          3          3
# 3499              51          7  4955.250          2          4          4
# 3500             144          6  1785.860          1          1          3
# 5034              84          3   269.485          2          1          1
#
# [3494 rows x 6 columns]

# %%
rfm['RFM_Score'] = rfm.r_quartile.astype(str) + rfm.f_quartile.astype(str) + rfm.m_quartile.astype(str)
rfm.head()
# Out:
#              recency  frequency  monetary r_quartile m_quartile f_quartile  \
# customer_id
# 1                  7         11   3018.09          4          3          4
# 2                128          3   2226.26          1          2          1
# 3                102          8   3362.81          1          3          4
# 4                195          2    220.57          1          1          1
# 5                 16          6   2394.94          4          2          2
#
#             RFM_Score
# customer_id
# 1                 443
# 2                 112
# 3                 143
# 4                 111
# 5                 422

# %%
# Filter out Top/Best cusotmers
rfm[rfm['RFM_Score']=='444'].sort_values('monetary',ascending=False)
# Out:
#              recency  frequency  monetary r_quartile m_quartile f_quartile  \
# customer_id
# 1460              12          8  10787.60          4          4          4
# 1558               8          9  10640.30          4          4          4
# 729                1         10  10497.78          4          4          4
# 322                1         12  10341.57          4          4          4
# 3232               8         13   8903.62          4          4          4
# ...              ...        ...       ...        ...        ...        ...
# 377                6         13   4276.97          4          4          4
# 2130               1          8   4253.77          4          4          4
# 577                2         11   4242.34          4          4          4
# 719               11          9   4227.84          4          4          4
# 1091               4         11   4183.81          4          4          4
#
#             RFM_Score
# customer_id
# 1460              444
# 1558              444
# 729               444
# 322               444
# 3232              444
# ...               ...
# 377               444
# 2130              444
# 577               444
# 719               444
# 1091              444
#
# [184 rows x 7 columns]

# %%
# Filter out Top/Best cusotmers
rfm[rfm['RFM_Score']=='111'].sort_values('monetary',ascending=False)
# Out:
#              recency  frequency  monetary r_quartile m_quartile f_quartile  \
# customer_id
# 2959             134          3   1835.26          1          1          1
# 1768              92          2   1821.07          1          1          1
# 170              100          4   1820.81          1          1          1
# 1209             131          2   1809.69          1          1          1
# 3457              97          3   1802.90          1          1          1
# ...              ...        ...       ...        ...        ...        ...
# 872              171          1     75.48          1          1          1
# 3272             295          1     41.13          1          1          1
# 922              188          2     41.13          1          1          1
# 2532             140          1     17.87          1          1          1
# 3292             301          1     15.08          1          1          1
#
#             RFM_Score
# customer_id
# 2959              111
# 1768              111
# 170               111
# 1209              111
# 3457              111
# ...               ...
# 872               111
# 3272              111
# 922               111
# 2532              111
# 3292              111
#
# [270 rows x 7 columns]

# %%
#Filter the scores and segment customers
print("Best Customers: ",len(rfm[rfm['RFM_Score']=='444']))
print('Loyal Customers: ',len(rfm[rfm['f_quartile']>='3']))
print("Big Spenders: ",len(rfm[rfm['m_quartile']=='4']))
print('Almost Lost: ', len(rfm[rfm['RFM_Score']=='111']))
# Out:
# Best Customers:  184
# Loyal Customers:  1747
# Big Spenders:  874
# Almost Lost:  270

# %% [markdown]
# ### Visualization

# %%
rfm.head()
# Out:
#              recency  frequency  monetary r_quartile m_quartile f_quartile  \
# customer_id
# 1                  7         11   3018.09          4          3          4
# 2                128          3   2226.26          1          2          1
# 3                102          8   3362.81          1          3          4
# 4                195          2    220.57          1          1          1
# 5                 16          6   2394.94          4          2          2
#
#             RFM_Score
# customer_id
# 1                 443
# 2                 112
# 3                 143
# 4                 111
# 5                 422

# %%
rfm=rfm.reset_index()

# %%
rfm
# Out:
#       customer_id  recency  frequency  monetary r_quartile m_quartile  \
# 0               1        7         11  3018.090          4          3
# 1               2      128          3  2226.260          1          2
# 2               3      102          8  3362.810          1          3
# 3               4      195          2   220.570          1          1
# 4               5       16          6  2394.940          4          2
# ...           ...      ...        ...       ...        ...        ...
# 3489         3497       52          3  1648.320          2          1
# 3490         3498      127          6  3147.330          1          3
# 3491         3499       51          7  4955.250          2          4
# 3492         3500      144          6  1785.860          1          1
# 3493         5034       84          3   269.485          2          1
#
#      f_quartile RFM_Score
# 0             4       443
# 1             1       112
# 2             4       143
# 3             1       111
# 4             2       422
# ...         ...       ...
# 3489          1       211
# 3490          3       133
# 3491          4       244
# 3492          3       131
# 3493          1       211
#
# [3494 rows x 8 columns]

# %%
rfm_merge=rfm.merge(mergedata,
                    left_on = 'customer_id',
                    right_on = 'customer_id',
                    how = 'left')

# %%
rfm_merge
# Out:
#        customer_id  recency  frequency  monetary r_quartile m_quartile  \
# 0                1        7         11  3018.090          4          3
# 1                1        7         11  3018.090          4          3
# 2                1        7         11  3018.090          4          3
# 3                1        7         11  3018.090          4          3
# 4                1        7         11  3018.090          4          3
# ...            ...      ...        ...       ...        ...        ...
# 19995         3500      144          6  1785.860          1          1
# 19996         3500      144          6  1785.860          1          1
# 19997         5034       84          3   269.485          2          1
# 19998         5034       84          3   269.485          2          1
# 19999         5034       84          3   269.485          2          1
#
#       f_quartile RFM_Score  transaction_id  product_id  ...  gender  \
# 0              4       443              94          86  ...       F
# 1              4       443            3765          38  ...       F
# 2              4       443            5157          47  ...       F
# 3              4       443            9785          72  ...       F
# 4              4       443           13424           2  ...       F
# ...          ...       ...             ...         ...  ...     ...
# 19995          3       131           14870          22  ...  Female
# 19996          3       131           19836          40  ...  Female
# 19997          1       211            8708           0  ...     NaN
# 19998          1       211           16701           0  ...     NaN
# 19999          1       211           17469           0  ...     NaN
#
#        past_3_years_bike_related_purchases        DOB            job_title  \
# 0                                     93.0 1953-10-12  Executive Secretary
# 1                                     93.0 1953-10-12  Executive Secretary
# 2                                     93.0 1953-10-12  Executive Secretary
# 3                                     93.0 1953-10-12  Executive Secretary
# 4                                     93.0 1953-10-12  Executive Secretary
# ...                                    ...        ...                  ...
# 19995                                 71.0 1967-07-21                  NaN
# 19996                                 71.0 1967-07-21                  NaN
# 19997                                  NaN        NaT                  NaN
# 19998                                  NaN        NaT                  NaN
# 19999                                  NaN        NaT                  NaN
#
#       job_industry_category     wealth_segment deceased_indicator  \
# 0                    Health      Mass Customer                  N
# 1                    Health      Mass Customer                  N
# 2                    Health      Mass Customer                  N
# 3                    Health      Mass Customer                  N
# 4                    Health      Mass Customer                  N
# ...                     ...                ...                ...
# 19995         Entertainment  Affluent Customer                  N
# 19996         Entertainment  Affluent Customer                  N
# 19997                   NaN                NaN                NaN
# 19998                   NaN                NaN                NaN
# 19999                   NaN                NaN                NaN
#
#                       default  owns_car tenure
# 0                          "'       Yes   11.0
# 1                          "'       Yes   11.0
# 2                          "'       Yes   11.0
# 3                          "'       Yes   11.0
# 4                          "'       Yes   11.0
# ...                       ...       ...    ...
# 19995  Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ         No   17.0
# 19996  Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ         No   17.0
# 19997                     NaN       NaN    NaN
# 19998                     NaN       NaN    NaN
# 19999                     NaN       NaN    NaN
#
# [20000 rows x 32 columns]

# %%
rfm_merge['transaction_date'].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
d=rfm_merge.duplicated(subset=None, keep='last')

# %%
d.value_counts()
# Out:
# False    20000
# dtype: int64

# %%
rfm_merge.columns
# Out:
# Index(['customer_id', 'recency', 'frequency', 'monetary', 'r_quartile',
#        'm_quartile', 'f_quartile', 'RFM_Score', 'transaction_id', 'product_id',
#        'transaction_date', 'online_order', 'order_status', 'brand',
#        'product_line', 'product_class', 'product_size', 'list_price',
#        'standard_cost', 'product_first_sold_date', 'first_name', 'last_name',
#        'gender', 'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
rfm_data=rfm_merge[['customer_id', 'recency', 'frequency', 'monetary', 'r_quartile',
       'm_quartile', 'f_quartile', 'RFM_Score', 'transaction_id', 'product_id',
       'transaction_date', 'online_order', 'order_status', 'brand',
       'product_line', 'product_class', 'product_size','gender', 'past_3_years_bike_related_purchases', 
                    'DOB', 'job_title','job_industry_category', 'wealth_segment', 'owns_car', 'tenure' ]]

# %%
rfm_data
# Out:
#        customer_id  recency  frequency  monetary r_quartile m_quartile  \
# 0                1        7         11  3018.090          4          3
# 1                1        7         11  3018.090          4          3
# 2                1        7         11  3018.090          4          3
# 3                1        7         11  3018.090          4          3
# 4                1        7         11  3018.090          4          3
# ...            ...      ...        ...       ...        ...        ...
# 19995         3500      144          6  1785.860          1          1
# 19996         3500      144          6  1785.860          1          1
# 19997         5034       84          3   269.485          2          1
# 19998         5034       84          3   269.485          2          1
# 19999         5034       84          3   269.485          2          1
#
#       f_quartile RFM_Score  transaction_id  product_id  ... product_class  \
# 0              4       443              94          86  ...        medium
# 1              4       443            3765          38  ...        medium
# 2              4       443            5157          47  ...           low
# 3              4       443            9785          72  ...        medium
# 4              4       443           13424           2  ...        medium
# ...          ...       ...             ...         ...  ...           ...
# 19995          3       131           14870          22  ...        medium
# 19996          3       131           19836          40  ...          high
# 19997          1       211            8708           0  ...        medium
# 19998          1       211           16701           0  ...        medium
# 19999          1       211           17469           0  ...        medium
#
#        product_size  gender past_3_years_bike_related_purchases        DOB  \
# 0            medium       F                                93.0 1953-10-12
# 1            medium       F                                93.0 1953-10-12
# 2             small       F                                93.0 1953-10-12
# 3            medium       F                                93.0 1953-10-12
# 4            medium       F                                93.0 1953-10-12
# ...             ...     ...                                 ...        ...
# 19995        medium  Female                                71.0 1967-07-21
# 19996        medium  Female                                71.0 1967-07-21
# 19997        medium     NaN                                 NaN        NaT
# 19998        medium     NaN                                 NaN        NaT
# 19999        medium     NaN                                 NaN        NaT
#
#                  job_title job_industry_category     wealth_segment  owns_car  \
# 0      Executive Secretary                Health      Mass Customer       Yes
# 1      Executive Secretary                Health      Mass Customer       Yes
# 2      Executive Secretary                Health      Mass Customer       Yes
# 3      Executive Secretary                Health      Mass Customer       Yes
# 4      Executive Secretary                Health      Mass Customer       Yes
# ...                    ...                   ...                ...       ...
# 19995                  NaN         Entertainment  Affluent Customer        No
# 19996                  NaN         Entertainment  Affluent Customer        No
# 19997                  NaN                   NaN                NaN       NaN
# 19998                  NaN                   NaN                NaN       NaN
# 19999                  NaN                   NaN                NaN       NaN
#
#       tenure
# 0       11.0
# 1       11.0
# 2       11.0
# 3       11.0
# 4       11.0
# ...      ...
# 19995   17.0
# 19996   17.0
# 19997    NaN
# 19998    NaN
# 19999    NaN
#
# [20000 rows x 25 columns]

# %%
PRESENT = dt.datetime(2020,8,26)

# %%
PRESENT
# Out:
# datetime.datetime(2020, 8, 26, 0, 0)

# %%
rfm_data['age']=PRESENT-rfm_data['DOB']

# %%
rfm_data['age']=rfm_data['age']/365

# %%
rfm_data
# Out:
#        customer_id  recency  frequency  monetary r_quartile m_quartile  \
# 0                1        7         11  3018.090          4          3
# 1                1        7         11  3018.090          4          3
# 2                1        7         11  3018.090          4          3
# 3                1        7         11  3018.090          4          3
# 4                1        7         11  3018.090          4          3
# ...            ...      ...        ...       ...        ...        ...
# 19995         3500      144          6  1785.860          1          1
# 19996         3500      144          6  1785.860          1          1
# 19997         5034       84          3   269.485          2          1
# 19998         5034       84          3   269.485          2          1
# 19999         5034       84          3   269.485          2          1
#
#       f_quartile RFM_Score  transaction_id  product_id  ... product_size  \
# 0              4       443              94          86  ...       medium
# 1              4       443            3765          38  ...       medium
# 2              4       443            5157          47  ...        small
# 3              4       443            9785          72  ...       medium
# 4              4       443           13424           2  ...       medium
# ...          ...       ...             ...         ...  ...          ...
# 19995          3       131           14870          22  ...       medium
# 19996          3       131           19836          40  ...       medium
# 19997          1       211            8708           0  ...       medium
# 19998          1       211           16701           0  ...       medium
# 19999          1       211           17469           0  ...       medium
#
#        gender past_3_years_bike_related_purchases        DOB  \
# 0           F                                93.0 1953-10-12
# 1           F                                93.0 1953-10-12
# 2           F                                93.0 1953-10-12
# 3           F                                93.0 1953-10-12
# 4           F                                93.0 1953-10-12
# ...       ...                                 ...        ...
# 19995  Female                                71.0 1967-07-21
# 19996  Female                                71.0 1967-07-21
# 19997     NaN                                 NaN        NaT
# 19998     NaN                                 NaN        NaT
# 19999     NaN                                 NaN        NaT
#
#                  job_title job_industry_category     wealth_segment owns_car  \
# 0      Executive Secretary                Health      Mass Customer      Yes
# 1      Executive Secretary                Health      Mass Customer      Yes
# 2      Executive Secretary                Health      Mass Customer      Yes
# 3      Executive Secretary                Health      Mass Customer      Yes
# 4      Executive Secretary                Health      Mass Customer      Yes
# ...                    ...                   ...                ...      ...
# 19995                  NaN         Entertainment  Affluent Customer       No
# 19996                  NaN         Entertainment  Affluent Customer       No
# 19997                  NaN                   NaN                NaN      NaN
# 19998                  NaN                   NaN                NaN      NaN
# 19999                  NaN                   NaN                NaN      NaN
#
#        tenure                     age
# 0        11.0 66 days 22:01:38.630136
# 1        11.0 66 days 22:01:38.630136
# 2        11.0 66 days 22:01:38.630136
# 3        11.0 66 days 22:01:38.630136
# 4        11.0 66 days 22:01:38.630136
# ...       ...                     ...
# 19995    17.0 53 days 03:17:15.616438
# 19996    17.0 53 days 03:17:15.616438
# 19997     NaN                     NaT
# 19998     NaN                     NaT
# 19999     NaN                     NaT
#
# [20000 rows x 26 columns]

# %%
now = dt.datetime.now()

# %%
rfm_data['age']=(now.year - rfm_data['DOB'].dt.year) - ((now.month - rfm_data['DOB'].dt.month) < 0)

# %%
rfm_data
# Out:
#        customer_id  recency  frequency  monetary r_quartile m_quartile  \
# 0                1        7         11  3018.090          4          3
# 1                1        7         11  3018.090          4          3
# 2                1        7         11  3018.090          4          3
# 3                1        7         11  3018.090          4          3
# 4                1        7         11  3018.090          4          3
# ...            ...      ...        ...       ...        ...        ...
# 19995         3500      144          6  1785.860          1          1
# 19996         3500      144          6  1785.860          1          1
# 19997         5034       84          3   269.485          2          1
# 19998         5034       84          3   269.485          2          1
# 19999         5034       84          3   269.485          2          1
#
#       f_quartile RFM_Score  transaction_id  product_id  ... product_size  \
# 0              4       443              94          86  ...       medium
# 1              4       443            3765          38  ...       medium
# 2              4       443            5157          47  ...        small
# 3              4       443            9785          72  ...       medium
# 4              4       443           13424           2  ...       medium
# ...          ...       ...             ...         ...  ...          ...
# 19995          3       131           14870          22  ...       medium
# 19996          3       131           19836          40  ...       medium
# 19997          1       211            8708           0  ...       medium
# 19998          1       211           16701           0  ...       medium
# 19999          1       211           17469           0  ...       medium
#
#        gender past_3_years_bike_related_purchases        DOB  \
# 0           F                                93.0 1953-10-12
# 1           F                                93.0 1953-10-12
# 2           F                                93.0 1953-10-12
# 3           F                                93.0 1953-10-12
# 4           F                                93.0 1953-10-12
# ...       ...                                 ...        ...
# 19995  Female                                71.0 1967-07-21
# 19996  Female                                71.0 1967-07-21
# 19997     NaN                                 NaN        NaT
# 19998     NaN                                 NaN        NaT
# 19999     NaN                                 NaN        NaT
#
#                  job_title job_industry_category     wealth_segment owns_car  \
# 0      Executive Secretary                Health      Mass Customer      Yes
# 1      Executive Secretary                Health      Mass Customer      Yes
# 2      Executive Secretary                Health      Mass Customer      Yes
# 3      Executive Secretary                Health      Mass Customer      Yes
# 4      Executive Secretary                Health      Mass Customer      Yes
# ...                    ...                   ...                ...      ...
# 19995                  NaN         Entertainment  Affluent Customer       No
# 19996                  NaN         Entertainment  Affluent Customer       No
# 19997                  NaN                   NaN                NaN      NaN
# 19998                  NaN                   NaN                NaN      NaN
# 19999                  NaN                   NaN                NaN      NaN
#
#        tenure   age
# 0        11.0  66.0
# 1        11.0  66.0
# 2        11.0  66.0
# 3        11.0  66.0
# 4        11.0  66.0
# ...       ...   ...
# 19995    17.0  53.0
# 19996    17.0  53.0
# 19997     NaN   NaN
# 19998     NaN   NaN
# 19999     NaN   NaN
#
# [20000 rows x 26 columns]

# %%
rfm_data.isnull().sum()
# Out:
# customer_id                               0
# recency                                   0
# frequency                                 0
# monetary                                  0
# r_quartile                                0
# m_quartile                                0
# f_quartile                                0
# RFM_Score                                 0
# transaction_id                            0
# product_id                                0
# transaction_date                          0
# online_order                            360
# order_status                              0
# brand                                   197
# product_line                            197
# product_class                           197
# product_size                            197
# gender                                    3
# past_3_years_bike_related_purchases       3
# DOB                                     449
# job_title                              2397
# job_industry_category                  3232
# wealth_segment                            3
# owns_car                                  3
# tenure                                  449
# age                                     449
# dtype: int64

# %%
rfm_data['gender'].value_counts()
# Out:
# Female    9993
# Male      9525
# U          455
# F           11
# Femal        7
# M            6
# Name: gender, dtype: int64

# %%
rfm_data['gender'].replace({"F":"Female", "M":"Male", "Femal":"Female", "U":"Unknown"}, inplace=True)

# %%
rfm_data['gender'].value_counts()
# Out:
# Female     10011
# Male        9531
# Unknown      455
# Name: gender, dtype: int64

# %%
rfm_data['age'].describe()
# Out:
# count    19551.000000
# mean        42.666871
# std         12.933177
# min         18.000000
# 25%         33.000000
# 50%         43.000000
# 75%         52.000000
# max        176.000000
# Name: age, dtype: float64

# %%
rfm_data[rfm_data['age']>100]
# Out:
#      customer_id  recency  frequency  monetary r_quartile m_quartile  \
# 200           34      102          9   4825.59          1          4
# 201           34      102          9   4825.59          1          4
# 202           34      102          9   4825.59          1          4
# 203           34      102          9   4825.59          1          4
# 204           34      102          9   4825.59          1          4
# 205           34      102          9   4825.59          1          4
# 206           34      102          9   4825.59          1          4
# 207           34      102          9   4825.59          1          4
# 208           34      102          9   4825.59          1          4
#
#     f_quartile RFM_Score  transaction_id  product_id  ... product_size  \
# 200          4       144            1039           8  ...        small
# 201          4       144            1107          15  ...       medium
# 202          4       144            2638          83  ...        large
# 203          4       144            9044          12  ...       medium
# 204          4       144            9792          60  ...        small
# 205          4       144           12083          13  ...       medium
# 206          4       144           16935           0  ...          NaN
# 207          4       144           17808          96  ...        small
# 208          4       144           19291          65  ...       medium
#
#       gender past_3_years_bike_related_purchases        DOB        job_title  \
# 200  Unknown                                59.0 1843-12-21  Legal Assistant
# 201  Unknown                                59.0 1843-12-21  Legal Assistant
# 202  Unknown                                59.0 1843-12-21  Legal Assistant
# 203  Unknown                                59.0 1843-12-21  Legal Assistant
# 204  Unknown                                59.0 1843-12-21  Legal Assistant
# 205  Unknown                                59.0 1843-12-21  Legal Assistant
# 206  Unknown                                59.0 1843-12-21  Legal Assistant
# 207  Unknown                                59.0 1843-12-21  Legal Assistant
# 208  Unknown                                59.0 1843-12-21  Legal Assistant
#
#     job_industry_category     wealth_segment owns_car  tenure    age
# 200                    IT  Affluent Customer       No    20.0  176.0
# 201                    IT  Affluent Customer       No    20.0  176.0
# 202                    IT  Affluent Customer       No    20.0  176.0
# 203                    IT  Affluent Customer       No    20.0  176.0
# 204                    IT  Affluent Customer       No    20.0  176.0
# 205                    IT  Affluent Customer       No    20.0  176.0
# 206                    IT  Affluent Customer       No    20.0  176.0
# 207                    IT  Affluent Customer       No    20.0  176.0
# 208                    IT  Affluent Customer       No    20.0  176.0
#
# [9 rows x 26 columns]

# %%
rfm_data['age']=rfm_data['age'].fillna(rfm_data['age'].median())

# %%
rfm_data['age'].describe()
# Out:
# count    19551.000000
# mean        42.666871
# std         12.933177
# min         18.000000
# 25%         33.000000
# 50%         43.000000
# 75%         52.000000
# max        176.000000
# Name: age, dtype: float64

# %%
rfm_data['tenure'].describe()
# Out:
# count    19551.000000
# mean        10.683239
# std          5.676403
# min          1.000000
# 25%          6.000000
# 50%         11.000000
# 75%         15.000000
# max         22.000000
# Name: tenure, dtype: float64

# %%
rfm_data.isnull().sum()
# Out:
# customer_id                               0
# recency                                   0
# frequency                                 0
# monetary                                  0
# r_quartile                                0
# m_quartile                                0
# f_quartile                                0
# RFM_Score                                 0
# transaction_id                            0
# product_id                                0
# transaction_date                          0
# online_order                            360
# order_status                              0
# brand                                   197
# product_line                            197
# product_class                           197
# product_size                            197
# gender                                    3
# past_3_years_bike_related_purchases       3
# DOB                                     449
# job_title                              2397
# job_industry_category                  3232
# wealth_segment                            3
# owns_car                                  3
# tenure                                  449
# age                                       0
# dtype: int64

# %%
rfm_data=rfm_data.drop(['DOB'], axis=1)

# %%
rfm_data = rfm_data.dropna(axis=0, subset=['tenure'])

# %%
rfm_data.isnull().sum()
# Out:
# customer_id                               0
# recency                                   0
# frequency                                 0
# monetary                                  0
# r_quartile                                0
# m_quartile                                0
# f_quartile                                0
# RFM_Score                                 0
# transaction_id                            0
# product_id                                0
# transaction_date                          0
# online_order                            352
# order_status                              0
# brand                                   189
# product_line                            189
# product_class                           189
# product_size                            189
# gender                                    0
# past_3_years_bike_related_purchases       0
# job_title                              2355
# job_industry_category                  3229
# wealth_segment                            0
# owns_car                                  0
# tenure                                    0
# age                                       0
# dtype: int64

# %%
# %matplotlib inline
plt.style.use('ggplot')

segments = ['BestCustomers', 'LoyalCustomers', 'BigSpender', 'AlmostLost']
counts = [184, 1747, 874, 270]

x_pos = [i for i, _ in enumerate(segments)]

plt.bar(x_pos, counts, color='blue')
plt.xlabel("Segments")
plt.ylabel("Count")
plt.title("Customer Segmentation based on RFM")

plt.xticks(x_pos, segments)

plt.show()

# %%
rfm_data['age_group'] = pd.cut(x=rfm_data['age'], bins=[18, 30, 55, 85], labels=['Young-Adults', 'Mid-Aged', 'Senior-Citizens'])

# %%
rfm_data
# Out:
#        customer_id  recency  frequency  monetary r_quartile m_quartile  \
# 0                1        7         11   3018.09          4          3
# 1                1        7         11   3018.09          4          3
# 2                1        7         11   3018.09          4          3
# 3                1        7         11   3018.09          4          3
# 4                1        7         11   3018.09          4          3
# ...            ...      ...        ...       ...        ...        ...
# 19992         3500      144          6   1785.86          1          1
# 19993         3500      144          6   1785.86          1          1
# 19994         3500      144          6   1785.86          1          1
# 19995         3500      144          6   1785.86          1          1
# 19996         3500      144          6   1785.86          1          1
#
#       f_quartile RFM_Score  transaction_id  product_id  ... product_size  \
# 0              4       443              94          86  ...       medium
# 1              4       443            3765          38  ...       medium
# 2              4       443            5157          47  ...        small
# 3              4       443            9785          72  ...       medium
# 4              4       443           13424           2  ...       medium
# ...          ...       ...             ...         ...  ...          ...
# 19992          3       131            6309          69  ...       medium
# 19993          3       131            8416          74  ...       medium
# 19994          3       131            8562          33  ...        small
# 19995          3       131           14870          22  ...       medium
# 19996          3       131           19836          40  ...       medium
#
#        gender past_3_years_bike_related_purchases            job_title  \
# 0      Female                                93.0  Executive Secretary
# 1      Female                                93.0  Executive Secretary
# 2      Female                                93.0  Executive Secretary
# 3      Female                                93.0  Executive Secretary
# 4      Female                                93.0  Executive Secretary
# ...       ...                                 ...                  ...
# 19992  Female                                71.0                  NaN
# 19993  Female                                71.0                  NaN
# 19994  Female                                71.0                  NaN
# 19995  Female                                71.0                  NaN
# 19996  Female                                71.0                  NaN
#
#       job_industry_category     wealth_segment owns_car tenure   age  \
# 0                    Health      Mass Customer      Yes   11.0  66.0
# 1                    Health      Mass Customer      Yes   11.0  66.0
# 2                    Health      Mass Customer      Yes   11.0  66.0
# 3                    Health      Mass Customer      Yes   11.0  66.0
# 4                    Health      Mass Customer      Yes   11.0  66.0
# ...                     ...                ...      ...    ...   ...
# 19992         Entertainment  Affluent Customer       No   17.0  53.0
# 19993         Entertainment  Affluent Customer       No   17.0  53.0
# 19994         Entertainment  Affluent Customer       No   17.0  53.0
# 19995         Entertainment  Affluent Customer       No   17.0  53.0
# 19996         Entertainment  Affluent Customer       No   17.0  53.0
#
#              age_group
# 0      Senior-Citizens
# 1      Senior-Citizens
# 2      Senior-Citizens
# 3      Senior-Citizens
# 4      Senior-Citizens
# ...                ...
# 19992         Mid-Aged
# 19993         Mid-Aged
# 19994         Mid-Aged
# 19995         Mid-Aged
# 19996         Mid-Aged
#
# [19551 rows x 26 columns]

# %%
rfm_data['age_group'].value_counts()
# Out:
# Mid-Aged           11951
# Young-Adults        3824
# Senior-Citizens     3662
# Name: age_group, dtype: int64

# %%
unique_rfm_data=rfm_data.drop_duplicates(subset ="customer_id")

# %%
unique_rfm_data.to_csv(r'/Users/naveen/Desktop/KPMG Virtual Internship/rfm_data.csv')

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,8))
ax = sns.countplot(x=unique_rfm_data['age_group'], data=unique_rfm_data, order = unique_rfm_data['age_group'].value_counts().index)
plt.title('Customers Age Group')
plt.xlabel('Age Groups')
plt.ylabel('Count')

for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+10))

# %%
unique_rfm_data['gender']
# Out:
# 0        Female
# 11         Male
# 14         Male
# 22         Male
# 24       Female
#           ...
# 19971      Male
# 19975    Female
# 19978    Female
# 19984      Male
# 19991    Female
# Name: gender, Length: 3417, dtype: object

# %%
unique_rfm_data=unique_rfm_data.loc[unique_rfm_data['gender']!='Unknown']

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(x=unique_rfm_data['gender'], data=unique_rfm_data)
plt.title('Sales by Gneder')
plt.xlabel('Gender')
plt.ylabel('Count')

for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+10))

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x=unique_rfm_data['wealth_segment'], data=unique_rfm_data, order = unique_rfm_data['wealth_segment'].value_counts().index)
plt.title('Waelth Segment of Customers')
plt.xlabel('Waelth Segment')
plt.ylabel('Count')

for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+10))

# %%
plt.figure(figsize=(16,10))
ax = sns.countplot(x=unique_rfm_data['job_industry_category'], data=unique_rfm_data,
                  order = unique_rfm_data['job_industry_category'].value_counts().index)
plt.title('Customers from Different Job Industry')
plt.xlabel('Job Industry')
plt.ylabel('Count')

for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+10))

# %%
newcustomer_df.groupby(['state','owns_car']).size().unstack().plot(kind='bar',stacked=True)
plt.title('Cars owned by State')
plt.show()
